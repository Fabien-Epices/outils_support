# %% [markdown]
# # Analyse des fichiers d'initialisation modubus (.ini)

# %% [markdown]
# librairies python utilisées...

# %%
from modbusDefinition import modbusDefinition
mb = modbusDefinition()

# %% [markdown]
# - parserDir() : choix des répertoire de lecture et éctiture
# - parse() :  choix du fichier à analyser

# %% [markdown]
# ## Choix des répertoires et des fichiers '.ini' à décoder
# -> lecture & écriture des données décodés

# %%
# fichiers de test (config client : Cayrol)
CustymerName = "Cayrol"
inputDir= "./FTP/" + CustymerName + "/DEF/MODBUS/"
outputDir= "./ZZZ/out/"
encoding=""

#fileList = [
#	"MODBUS_DELTA_Sunspec_RPI-M50A-1.43.ini", 
#	"MODBUS_DELTA_Sunspec_RPI-M50A-1.46.ini", 
#	"MODBUS_DELTA_Sunspec_RPI-M50A.ini", 
#]

fileList = "all"

# %%
# fichiers de test (config client : Agrisoleil)
CustymerName = "agrisoleil"
inputDir= "./FTP/" + CustymerName + "/DEF/MODBUS/"
outputDir= "./ZZZ/out/"
encoding=""

fileList = "all"

# %%
# fichiers de test (config client : Emasolar)
CustymerName = "emasolar"
inputDir= "./FTP/" + CustymerName + "/DEF/MODBUS/"
outputDir= "./ZZZ/out/"
encoding=""

fileList = "MODBUS_SUNGROW_TL.ini"
#fileList = "all"

# %% [markdown]
# ## Affichage des données du '.ini' décodées

# %%
mb.parserDir(inputDir, outputDir)
#for f in fileList :
#	print(inputDir + f)

print(" ----------------                décodage                ---------------- ")
mb.iniFilesParser(fileList, "csv, debug", encoding, skipUnreadVal= False , verbose=False)
# Out:
#  ----------------                décodage                ----------------
#   ...  import de ./FTP/emasolar/DEF/MODBUS/MODBUS_SUNGROW_TL.ini
#  ==== analyse de ./FTP/emasolar/DEF/MODBUS/MODBUS_SUNGROW_TL.ini ====
# # Description of fields
# # Id;Name;ReadFctCode;WriteFctCode;StartReg;NbReg;EnableReading;EnableWritting;Option1;Option2;;
# # Description of fields;;;;;;;;;;;
# # varIndex;varReqIndex;varName;varType;varSigned;varPosition;varOption1;varOption2;varCoeffA;varCoeffB;varUnit;varAction
# #2: PID repair running;;;;;;;;;;;
# #4: PID protection running;;;;;;;;;;;
# #8: PID abnormal;;;;;;;;;;;
# #432: PID resistance abnormal;;;;;;;;;;;
# #433: PID function abnormal;;;;;;;;;;;
# #434: PID overvoltage/overcurrent protection;;;;;;;;;;;
# #76;13;current.inverter_entry.1;3;2;1;;;0.01;0;A;4
# #77;13;current.inverter_entry.2;3;2;2;;;0.01;0;A;4
# #78;13;current.inverter_entry.3;3;2;3;;;0.01;0;A;4
# #79;13;current.inverter_entry.4;3;2;4;;;0.01;0;A;4
# ...
